# %% [markdown]
# # Temporal Clustering

# %%
import psycopg2, multiprocessing, psycopg2.extras, os, json, sys, time
from multiprocessing import Pool, Manager 
import pandas as pd
import geopandas as gpd
from shapely.geometry import shape
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
working_data = '../working_data/clustered_with_speed/'

# %%
files = os.listdir(working_data)#[:100]

# %%
def loader_function(args):
    uFile, q = args
    u = json.load(open("../working_data/clustered_with_speed/"+uFile,'r'))
    tweets = []
    for t in u['features']:
        t['properties']['geometry'] = shape(t['geometry'])
        t['properties']['date'] = pd.Timestamp(t['properties']['date'])
        tweets.append(t['properties'])
    q.put(1)
    return gpd.GeoDataFrame(tweets)

# %%
#Parallel runtime
p = Pool(24)
m = Manager()
q = m.Queue()

args = [(i, q) for i in files]
result = p.map_async(loader_function, args)

# monitor loop
while True:
    if result.ready():
        break
    else:
        size = q.qsize()
        sys.stderr.write("\rProcessed: {0}, {1:.2g}%".format(size, size/len(args)*100))
        time.sleep(0.5)
users = result.get()
# Out:
# Processed: 20533, 1%

# %%
len(users)
# Out:
# 20533

# %% [markdown]
# # Identifying Temporal Clusters
# Using the same DBScan algorithm, we can find the common tweeting times for every spatial cluster

# %%
import numpy as np
import dbscan, imp
imp.reload(dbscan)
# Out:
# <module 'dbscan' from '/home/anderstj/Twitter-Movement-Derivation/TimeProcessing/dbscan.py'>

# %%
def worker_function(args):
    userDF, q = args
    times = np.array([list(userDF.date.astype(np.int64).apply(lambda x: x//1000000000))])
    userDF['time_cluster'] = dbscan.dbscan(times, 4*3600, 2)
    q.put(1)
    return userDF

# %%
#Parallel runtime
p = Pool(24)
m = Manager()
q = m.Queue()

args = [(i, q) for i in users]
result = p.map_async(worker_function, args)

# monitor loop
while True:
    if result.ready():
        break
    else:
        size = q.qsize()
        sys.stderr.write("\rProcessed: {0}, {1:.2g}%".format(size, size/len(args)*100))
        time.sleep(0.5)

users = result.get()
# Out:
# Processed: 20533, 1e+02%

# %%
users[0]
# Out:
#    cluster                       coords                      date  \
# 0     None    [-73.95891598, 40.710655] 2012-09-01 00:55:56+00:00
# 1     None      [-73.986764, 40.719607] 2012-09-05 23:21:52+00:00
# 2     None  [-73.99077645, 40.73639438] 2012-09-07 13:33:31+00:00
# 3     None  [-74.04568997, 40.71875291] 2012-09-08 18:59:30+00:00
# 4     None  [-74.05938719, 40.72143496] 2012-09-09 16:10:14+00:00
# 5     None  [-73.98633448, 40.76004046] 2012-09-10 22:06:53+00:00
# 6     None       [-73.87122, 40.773839] 2012-09-11 12:46:29+00:00
# 7     None  [-74.00150299, 40.70700073] 2012-09-11 14:13:17+00:00
# 8     None      [-73.999191, 40.732381] 2012-09-13 01:28:25+00:00
# 9     None  [-73.98842922, 40.71774704] 2012-09-15 21:44:13+00:00
# 10    None  [-73.98842922, 40.71774704] 2012-09-15 21:50:58+00:00
# 11    None  [-74.05938719, 40.72143496] 2012-09-15 23:03:28+00:00
# 12    None  [-73.98287954, 40.69170793] 2012-09-23 19:25:55+00:00
# 14  Masts  @ South Street Seaport http://t.co/QJXh...       695.0
# 15  Just posted a photo  @ Clipper City Sailboat h...      2864.0
# 16  Kick'in of @UnitedWayNYC #BridgeWalk ! Who's w...     51107.0
# 17  Brooklyn Brunch #Octoberfest style (@ Buschens...      9697.0
# 18  I'm at Blue Bottle Coffee (New York, NY) w/ 2 ...     79109.0
# 19  Best pork sandwich I've had in a loooong time!...    525781.0
# 20   Fall #sunrise  @ m650 Flats http://t.co/q78al3jo     68992.0
# 21  I'm at BLT Steak (New York, NY) w/ 2 others ht...    393234.0
# 22  Absolutely stunning sunset tonight! http://t.c...     79371.0
# 23  Doing a little pre-trip shopping then it's off...     81284.0
# 24    Dinner. (@ Koi Restaurant) http://t.co/Th4Oq8L0      4716.0
# 25  Landed. Now, lemme off! @real_genevieve should...    782689.0
# 26  Reflections in the Flood #huricanesandy  @ 636...   1001237.0
# 27  My friend, and 1 of the owners of Turtle Club,...       230.0
# 28  A much need beverage...new vintage is out. Che...    559243.0
# 29  @JohnGidding just got a @LuxeGuides for #Istan...     60949.0
# 30  Early morning fog coming up on the Hudson Rive...    147280.0
# 31  Wrapped in fog on the Pulaski Skyway @ Pulaski...     11279.0
# 32   Sunrise @ Beaver Dam Bridge http://t.co/pC2VmiGg    336038.0
# 33  Devastating. This photo does no justice. @ Sea...     16194.0
# 34  Beyond Words...and now we r heading to the wor...       291.0
# 35  @theellenshow this does the devastation no jus...      2055.0
# 36  cols6 &amp; I standing on the beach #Hurricane...      2390.0
# 37  GREAT meeting w/the guys from @FieldLens Can't...    423253.0
# 38  Art installation on the @highlinenyc http://t....     94714.0
# 39                            xo http://t.co/GDegz6oZ      2292.0
# 40                 Silver Bricks http://t.co/sbEAFIsC       331.0
#
#               user  time_cluster
# 0   CarrinoAnthony           1.0
# 1   CarrinoAnthony           2.0
# 2   CarrinoAnthony           3.0
# 3   CarrinoAnthony           4.0
# 4   CarrinoAnthony           5.0
# 5   CarrinoAnthony           6.0
# 6   CarrinoAnthony           7.0
# 7   CarrinoAnthony           7.0
# 8   CarrinoAnthony           2.0
# 9   CarrinoAnthony           4.0
# 10  CarrinoAnthony           4.0
# 11  CarrinoAnthony           4.0
# 12  CarrinoAnthony           5.0
# 13  CarrinoAnthony           1.0
# 14  CarrinoAnthony           1.0
# 15  CarrinoAnthony           1.0
# 16  CarrinoAnthony           8.0
# 17  CarrinoAnthony           8.0
# 18  CarrinoAnthony           NaN
# 19  CarrinoAnthony           8.0
# 20  CarrinoAnthony           NaN
# 21  CarrinoAnthony           NaN
# 22  CarrinoAnthony           1.0
# 23  CarrinoAnthony           4.0
# 24  CarrinoAnthony           4.0
# 25  CarrinoAnthony           6.0
# 26  CarrinoAnthony           8.0
# 27  CarrinoAnthony           8.0
# 28  CarrinoAnthony           1.0
# 29  CarrinoAnthony           8.0
# 30  CarrinoAnthony           9.0
# 31  CarrinoAnthony           9.0
# 32  CarrinoAnthony           NaN
# 33  CarrinoAnthony           3.0
# 34  CarrinoAnthony           3.0
# 35  CarrinoAnthony           3.0
# 36  CarrinoAnthony           3.0
# 37  CarrinoAnthony           NaN
# 38  CarrinoAnthony          10.0
# 39  CarrinoAnthony          10.0
# 40  CarrinoAnthony          10.0

# %%
corrs = [u.corr() for u in users[:10]]

# %%
corrs
# Out:
# [              geo_delta     speed  time_delta  time_cluster
#  geo_delta      1.000000 -0.002907    0.273859      0.078790
#  speed         -0.002907  1.000000   -0.318680      0.221705
#  time_delta     0.273859 -0.318680    1.000000     -0.020059
#  time_cluster   0.078790  0.221705   -0.020059      1.000000,
#              geo_delta     speed  time_delta
#  geo_delta    1.000000  0.997830   -0.729878
#  speed        0.997830  1.000000   -0.683282
#  time_delta  -0.729878 -0.683282    1.000000,
#              geo_delta     speed  time_delta
#  geo_delta    1.000000  0.079296   -0.569180
#  speed        0.079296  1.000000   -0.827751
#  time_delta  -0.569180 -0.827751    1.000000,
#              geo_delta     speed  time_delta
#  geo_delta    1.000000  0.988160   -0.848646
#  speed        0.988160  1.000000   -0.824503
#  time_delta  -0.848646 -0.824503    1.000000,
#                geo_delta  speed  time_delta  time_cluster
#  geo_delta           1.0   -1.0         1.0           NaN
#  speed              -1.0    1.0        -1.0           NaN
#  time_delta          1.0   -1.0         1.0           NaN
#  time_cluster        NaN    NaN         NaN           NaN,
#                geo_delta     speed  time_delta  time_cluster
#  geo_delta      1.000000 -0.005359   -0.134861     -0.083911
#  speed         -0.005359  1.000000   -0.218054      0.388607
#  time_delta    -0.134861 -0.218054    1.000000      0.398548
#  time_cluster  -0.083911  0.388607    0.398548      1.000000,
#                 cluster  geo_delta     speed  time_delta  time_cluster
#  cluster       1.000000   0.175513  0.192599    0.001517      0.089097
#  geo_delta     0.175513   1.000000  0.040369    0.701993     -0.041135
#  speed         0.192599   0.040369  1.000000   -0.083656     -0.154523
#  time_delta    0.001517   0.701993 -0.083656    1.000000     -0.001934
#  time_cluster  0.089097  -0.041135 -0.154523   -0.001934      1.000000,
#              geo_delta     speed  time_delta
#  geo_delta    1.000000 -0.710785     0.86424
#  speed       -0.710785  1.000000    -0.96816
#  time_delta   0.864240 -0.968160     1.00000,
#              geo_delta  speed  time_delta
#  geo_delta         NaN    NaN         NaN
#  speed             NaN    NaN         NaN
#  time_delta        NaN    NaN         NaN,
#                 cluster  geo_delta     speed  time_delta  time_cluster
#  cluster       1.000000   0.293267 -0.244092    0.253008      0.750662
#  geo_delta     0.293267   1.000000  0.107297    0.126686      0.132376
#  speed        -0.244092   0.107297  1.000000   -0.205224     -0.235698
#  time_delta    0.253008   0.126686 -0.205224    1.000000      0.202721
#  time_cluster  0.750662   0.132376 -0.235698    0.202721      1.000000]

# %%
fig, ax = plt.subplots(1)
ax.plot(sorted(corrs), range(len(corrs)))
