# %% [markdown]
# # Examining the Geographically Vulnerable (v2)

# %%
import pandas as pd; import numpy as np; from multiprocessing import Pool, Manager; import numpy as np; import geopandas as gpd
import matplotlib.pyplot as plt; import seaborn as sns
import matplotlib, os, json, sys, time, datetime
from bson import json_util

# %%
input_directory = "/data/chime/geo2/PROCESSED/NYC/ZoneA_Stage3/"
zoneGeometry     = "../EvacuationZones/NewYorkCity/EvacZoneA.shp"

# %% [markdown]
# #### Import the Zone Geometry

# %%
import fiona, shapely; from osgeo import ogr; from shapely.geometry import mapping, shape
c = fiona.open(zoneGeometry,'r')
pol = c.next(); zone = shape(pol['geometry']).buffer(0); zone.is_valid
# Out:
# True

# %% [markdown]
# ## 0. Import all of the individual user dataframes

# %%
users_in = sorted(os.listdir(input_directory))
users_in = [x for x in users_in if x != "temporal_clustered_user_meta.json"]
print("Found {0} users in {1}".format(len(users_in), input_directory))
# Out:
# Found 233 users in /data/chime/geo2/PROCESSED/NYC/ZoneA_Stage3/

# %%
def loader_function(args):
    uFile, path, q = args
    u = json.load(open(path+"/"+uFile,'r'))
    tweets = []
    for t in u['features']:
        if t['geometry']:
            t['properties']['geometry'] = shape(t['geometry'])
        t['properties']['date'] = pd.Timestamp(t['properties']['date'])
        tweets.append(t['properties'])
    q.put(1)
    return gpd.GeoDataFrame(tweets)

# %%
#Parallel runtime
p = Pool(30)
m = Manager()
q = m.Queue()

args = [(i, input_directory, q) for i in users_in]
result = p.map_async(loader_function, args)

# monitor loop
while True:
    if result.ready():
        break
    else:
        size = q.qsize()
        sys.stderr.write("\rProcessed: {0}, {1:.3g}%".format(size, size/len(args)*100))
        time.sleep(0.5)
sys.stderr.write("\rProcessed: {0}, {1:.3g}%".format(q.qsize(), q.qsize()/len(args)*100))
users = result.get()
p.close()
# Out:
# Processed: 233, 100%

# %% [markdown]
# ## The `users` array is an array of GeoDataFrames

# %%
users.sort( key=lambda x: len(x), reverse=True )

# %%
user_names = [x.user[0] for x in users]
user_names[:5]
# Out:
# ['NZavaa', '_an_oak_tree_', 'MyLuvisKING', 'brianaaanicolee', 'objorionto']

# %%
# Out:
#       cluster                                     cluster_center  \
# 0           1  {"type": "Point", "coordinates": [-73.80519066...
# 1           1  {"type": "Point", "coordinates": [-73.80519066...
# 2           1  {"type": "Point", "coordinates": [-73.80519066...
# 3           2  {"type": "Point", "coordinates": [-73.80392010...
# 4           1  {"type": "Point", "coordinates": [-73.80519066...
# 5           1  {"type": "Point", "coordinates": [-73.80519066...
# 6           1  {"type": "Point", "coordinates": [-73.80519066...
# 7           1  {"type": "Point", "coordinates": [-73.80519066...
# 8           1  {"type": "Point", "coordinates": [-73.80519066...
# 9           1  {"type": "Point", "coordinates": [-73.80519066...
# 10          1  {"type": "Point", "coordinates": [-73.80519066...
# 11          1  {"type": "Point", "coordinates": [-73.80519066...
# 12          1  {"type": "Point", "coordinates": [-73.80519066...
# 13          1  {"type": "Point", "coordinates": [-73.80519066...
# 14          1  {"type": "Point", "coordinates": [-73.80519066...
# 15          1  {"type": "Point", "coordinates": [-73.80519066...
# 16          2  {"type": "Point", "coordinates": [-73.80392010...
# 17          1  {"type": "Point", "coordinates": [-73.80519066...
# 18          1  {"type": "Point", "coordinates": [-73.80519066...
# 19          1  {"type": "Point", "coordinates": [-73.80519066...
# 20          1  {"type": "Point", "coordinates": [-73.80519066...
# 21          1  {"type": "Point", "coordinates": [-73.80519066...
# 22          1  {"type": "Point", "coordinates": [-73.80519066...
# 23          1  {"type": "Point", "coordinates": [-73.80519066...
# 24          1  {"type": "Point", "coordinates": [-73.80519066...
# 25          1  {"type": "Point", "coordinates": [-73.80519066...
# 26          1  {"type": "Point", "coordinates": [-73.80519066...
# 27          1  {"type": "Point", "coordinates": [-73.80519066...
# 28          1  {"type": "Point", "coordinates": [-73.80519066...
# 29          2  {"type": "Point", "coordinates": [-73.80392010...
# ...       ...                                                ...
# 3432        2  {"type": "Point", "coordinates": [-73.80392010...
# 3433        2  {"type": "Point", "coordinates": [-73.80392010...
# 3434        2  {"type": "Point", "coordinates": [-73.80392010...
# 3435        2  {"type": "Point", "coordinates": [-73.80392010...
# 3436        8  {"type": "Point", "coordinates": [-73.79773512...
# 3437        9  {"type": "Point", "coordinates": [-73.82683674...
# 3438        2  {"type": "Point", "coordinates": [-73.80392010...
# 3439        2  {"type": "Point", "coordinates": [-73.80392010...
# 3440       12  {"type": "Point", "coordinates": [-73.79982125...
# 3441       12  {"type": "Point", "coordinates": [-73.79982125...
# 3442       -1                                               null
# 3443        2  {"type": "Point", "coordinates": [-73.80392010...
# 3444        2  {"type": "Point", "coordinates": [-73.80392010...
# 3445        8  {"type": "Point", "coordinates": [-73.79773512...
# 3446        2  {"type": "Point", "coordinates": [-73.80392010...
# 3447        2  {"type": "Point", "coordinates": [-73.80392010...
# 3448        2  {"type": "Point", "coordinates": [-73.80392010...
# 3449        8  {"type": "Point", "coordinates": [-73.79773512...
# 3450        2  {"type": "Point", "coordinates": [-73.80392010...
# 3451        2  {"type": "Point", "coordinates": [-73.80392010...
# 3452        2  {"type": "Point", "coordinates": [-73.80392010...
# 3453        2  {"type": "Point", "coordinates": [-73.80392010...
# 3454        2  {"type": "Point", "coordinates": [-73.80392010...
# 3455        2  {"type": "Point", "coordinates": [-73.80392010...
# 3456        2  {"type": "Point", "coordinates": [-73.80392010...
# 3457        2  {"type": "Point", "coordinates": [-73.80392010...
# 3458        2  {"type": "Point", "coordinates": [-73.80392010...
# 3459        2  {"type": "Point", "coordinates": [-73.80392010...
# 3460        2  {"type": "Point", "coordinates": [-73.80392010...
# 3461        2  {"type": "Point", "coordinates": [-73.80392010...
#
#                            coords                      date  day_cluster  \
# 0      [-73.80524868, 40.7950463] 2012-09-09 19:49:57+00:00           10
# 1     [-73.80524798, 40.79504563] 2012-09-09 19:50:29+00:00           10
# 20       0.263781  POINT (-73.80521133000001 40.79513467)              NaN
# 21       0.157306        POINT (-73.80520953 40.79513505)              NaN
# 22       0.247298        POINT (-73.80520833 40.79513302)              NaN
# 23       4.635467         POINT (-73.8052596 40.79514823)              NaN
# 24      16.863600        POINT (-73.80507588 40.79508777)              NaN
# 25       5.336694         POINT (-73.8051392 40.79509012)              NaN
# 26       0.269754         POINT (-73.80513607 40.7950896)              NaN
# 27       1.944839  POINT (-73.80511919999999 40.79507765)              NaN
# 28      11.447245  POINT (-73.80520172999999 40.79499583)              NaN
# 29    1859.617194          POINT (-73.8032221 40.8116525)              NaN
# ...           ...                                     ...              ...
# 3432  1223.144230          POINT (-73.8045595 40.8103792)              NaN
# 3433     0.000000          POINT (-73.8045595 40.8103792)              NaN
# 3434     0.000000          POINT (-73.8045595 40.8103792)              NaN
# 3435     0.000000          POINT (-73.8045595 40.8103792)              NaN
# 3436  1325.546840          POINT (-73.7983153 40.7994353)              NaN
# 3437  3579.854365          POINT (-73.8291983 40.8215737)              NaN
# 3438  2418.396187          POINT (-73.8045595 40.8103792)              NaN
# 3439     0.000000          POINT (-73.8045595 40.8103792)              NaN
# 3440   883.700881   POINT (-73.80039669999999 40.8030832)              NaN
# 3441     0.000000   POINT (-73.80039669999999 40.8030832)              NaN
# 3442   355.430343           POINT (-73.8044919 40.803863)              NaN
# 3443   724.590719          POINT (-73.8045595 40.8103792)              NaN
# 3444     0.000000          POINT (-73.8045595 40.8103792)              NaN
# 3445  1325.546840          POINT (-73.7983153 40.7994353)              NaN
# 3446  1325.546840          POINT (-73.8045595 40.8103792)              NaN
# 3447     0.000000          POINT (-73.8045595 40.8103792)              NaN
# 3448     0.000000          POINT (-73.8045595 40.8103792)              NaN
# 3449  1325.546840          POINT (-73.7983153 40.7994353)              NaN
# 3450  1325.546840          POINT (-73.8045595 40.8103792)              NaN
# 3451     0.000000          POINT (-73.8045595 40.8103792)              NaN
# 3452     0.000000          POINT (-73.8045595 40.8103792)              NaN
# 3453     0.000000          POINT (-73.8045595 40.8103792)              NaN
# 3454     0.000000          POINT (-73.8045595 40.8103792)              NaN
# 3455     0.000000          POINT (-73.8045595 40.8103792)              NaN
# 3456     0.000000          POINT (-73.8045595 40.8103792)              NaN
# 3457    20.433475           POINT (-73.804641 40.8102061)              NaN
# 3458     0.000000           POINT (-73.804641 40.8102061)              NaN
# 3459     0.000000           POINT (-73.804641 40.8102061)              NaN
# 3460     0.000000           POINT (-73.804641 40.8102061)              NaN
# 3461     0.000000           POINT (-73.804641 40.8102061)              NaN
#
#           speed                                               text  \
# 0           NaN  @DaRealJimmyHils @OnPointDHH lmaooo ummm yes i...
# 1      0.002968  @OnPointDHH @DaRealJimmyHils id trust Romo ove...
# 2      0.010498  @Allen_Strk dude hes good, but what has he don...
# 3     88.349285  @Allen_Strk threat and you cant make it passed...
# 4     10.070286  @Allen_Strk i think Matt Ryan is fuckin beast....
# 5      0.434908        @Dirty30DaCorta RG3 just anally raped Brees
# 6      0.252393  @DaRealJimmyHils @OnPointDHH its the Bills tho...
# 7      0.322245  @DaRealJimmyHils @OnPointDHH at the end of the...
# 8      0.178502  @DaRealJimmyHils i no what u mean, i aint even...
# 9      0.061891  @Dirty30DaCorta him and Garcon, are nothing tt...
# 10     0.004083   New York footballs run game is a damn shame.....
# 11     0.011664                               RG3 is the real deal
# 12     0.013464  @Its_Delgado @Ndais10 tbh im scared shitless o...
# 13     0.011013  This 49er and Packers game is gonna be one of ...
# 14     0.065759  @OnPointDHH lmfao no he wasnt, RG3 and Matt Ry...
# 15     0.003059  @DaRealJimmyHils @OnPointDHH best tweet ii hav...
# 16    13.880695                       Randy Moss is that nigga lol
# 17    87.792875                        @OnPointDHH Eli has 2 rings
# 18     0.001131   @OnPointDHH how any were you able to watch? Lmao
# 19     0.014778  @OnPointDHH lmfaooo nah nahh, how any did you ...
# 20     0.001233  @OnPointDHH that means you know what u had for...
# 21     0.000307    @mandabeann @Cristina_Tabs both of you eat poop
# 22     0.000404                              Randy Moss is the man
# 23     0.002267       @DaRealJimmyHils there mad funny though lmao
# 24     0.020590  If Akers makes this, i will find where he live...
# 25     0.009379  I cant deal with some of these women reporters...
# 26     0.001775       Your just sooo damn sexy.......when your mad
# 27     0.002675  @Cristina_Tabs @ElenaIannece do NOT talk to my...
# 28     0.004871  I didnt wanna sing too loud i didnt wanna wake...
# 29     1.205977                              @Cristina_Tabs meeeee
# ...         ...                                                ...
# 3432  21.088694  #TweetYourFear being trapped in the Bronx Zoo ...
# 3433   0.000000       #TweetYourFear graduating from QueensBorough
# 3434   0.000000              #TweetYourFear going to QueensBorough
# 3435   0.000000            #TweetYourFear working at QueensBorough
# 3436  12.869387  #TweetYourFear losing my virginity........i lo...
# 3437  38.083557  #TweetYourFear watching a gay porn....the girl...
# 3438   2.993065  @juan_barreneche dude ive been on my grind for...
# 3439   0.000000                         @julia_river mee u bum ass
# 3440  18.034712  #TweetYourFear my dad telling me hes not my da...
# 3441   0.000000                   #TweetYourFear your fear........
# 3442  13.164087  #TweetYourFear going out and someone stepping ...
# 3443  12.712118  #TweetYourFear pornstars go on strike............
# 3444   0.000000  #TweetYourFear having a woman as president.......
# 3445  17.214894  #TweetYourFear a hott girl farting during sex....
# 3446  55.231118                     @Matt_Frank12 YOU DON SAY THAT
# 3447   0.000000         @Dirty30DaCorta im not about that life man
# 3448   0.000000  #TweetYourFear how am i supposed to tweet your...
# 3449   8.663705  #TweetYourFear all of my socks getting a hole ...
# 3450  12.624256  #TweetYourFear getting high and than having to...
# 3451   0.000000  @Matt_Frank12 idc how nice the kid was, when h...
# 3452   0.000000              #TweetYourFear meeting Hilary Clinton
# 3453   0.000000  Im done.....goodnight twitter. You now know wh...
# 3454   0.000000  Lemme throw in, i dont really have friends and...
# 3455   0.000000  @M_att_W @Matt_Frank12 @AlexaTellsAll Ari on f...
# 3456   0.000000  Shoutout to @juan_barreneche for knowing me on...
# 3457   0.000551          @mishpep yoo i say this everyday its nuts
# 3458   0.000000                 @Aphroditeeex lmfoaooo basicallly.
# 3459   0.000000                    @BiancaaSimonee schools closed?
# 3460   0.000000  @Trev_Stark so did everyone with a TV YOU BIG ...
# 3461   0.000000  @Trev_Stark howd u see em live? Did they vs th...
#
#       time_delta            tweet_id        uid    user
# 0            NaN  244885375221379072  284851512  NZavaa
# 1           32.0  244885509946609666  284851512  NZavaa
# 2           99.0  244885924939431936  284851512  NZavaa
# 3           21.0  244886011421798400  284851512  NZavaa
# 4          182.0  244886776056000512  284851512  NZavaa
# 5          243.0  244887793178910720  284851512  NZavaa
# 6          153.0  244888436710977537  284851512  NZavaa
# 7           17.0  244888507770888192  284851512  NZavaa
# 8          127.0  244889041399590912  284851512  NZavaa
# 9           30.0  244889165563568129  284851512  NZavaa
# 10         299.0  244890417403944960  284851512  NZavaa
# 11         434.0  244892239103418368  284851512  NZavaa
# 12          23.0  244892335752740865  284851512  NZavaa
# 13        1022.0  244896621421264896  284851512  NZavaa
# 14          35.0  244896770168061952  284851512  NZavaa
# 15         618.0  244899360289218560  284851512  NZavaa
# 16         133.0  244899920635625474  284851512  NZavaa
# 17          21.0  244900009621995521  284851512  NZavaa
# 18          96.0  244900410932985857  284851512  NZavaa
# 19          65.0  244900684074479616  284851512  NZavaa
# 20         214.0  244901581164777472  284851512  NZavaa
# 21         512.0  244903729411796992  284851512  NZavaa
# 22         612.0  244906296363610112  284851512  NZavaa
# 23        2045.0  244914874306682881  284851512  NZavaa
# 24         819.0  244918308191735808  284851512  NZavaa
# 25         569.0  244920695115620352  284851512  NZavaa
# 26         152.0  244921332641460224  284851512  NZavaa
# 27         727.0  244924379593576448  284851512  NZavaa
# 28        2350.0  244934239420829696  284851512  NZavaa
# 29        1542.0  244940705087242240  284851512  NZavaa
# ...          ...                 ...        ...     ...
# 3432        58.0  266412197519953920  284851512  Zav718
# 3433        33.0  266412335860695041  284851512  Zav718
# 3434         7.0  266412366349090816  284851512  Zav718
# 3435        22.0  266412458607013888  284851512  Zav718
# 3436       103.0  266412891509506048  284851512  Zav718
# 3437        94.0  266413284738072576  284851512  Zav718
# 3438       808.0  266416671860862978  284851512  Zav718
# 3439         2.0  266416680626962432  284851512  Zav718
# 3440        49.0  266416887682957312  284851512  Zav718
# 3441        17.0  266416959653023745  284851512  Zav718
# 3442        27.0  266417071452196864  284851512  Zav718
# 3443        57.0  266417310758232064  284851512  Zav718
# 3444        16.0  266417377737048064  284851512  Zav718
# 3445        77.0  266417703567380481  284851512  Zav718
# 3446        24.0  266417803731542016  284851512  Zav718
# 3447        29.0  266417922287730689  284851512  Zav718
# 3448        67.0  266418202806988800  284851512  Zav718
# 3449       153.0  266418845328216064  284851512  Zav718
# 3450       105.0  266419287705665537  284851512  Zav718
# 3451        44.0  266419471109980160  284851512  Zav718
# 3452        62.0  266419731165237248  284851512  Zav718
# 3453        19.0  266419809393209344  284851512  Zav718
# 3454        25.0  266419916700266496  284851512  Zav718
# 3455       121.0  266420423275732992  284851512  Zav718
# 3456        41.0  266420596131393537  284851512  Zav718
# 3457     37109.0  266576244005556225  284851512  Zav718
# 3458        40.0  266576407679877120  284851512  Zav718
# 3459        57.0  266576650576203776  284851512  Zav718
# 3460       193.0  266577456440418306  284851512  Zav718
# 3461       321.0  266578806507200512  284851512  Zav718
#
# [3462 rows x 14 columns]

# %%
def get_home_cluster_center(userDF):
    return shape(json.loads(userDF.query('cluster=='+str(userDF.home_cluster_id.values[0])).cluster_center.values[0]))

get_home_cluster_center(users[0]).within(zone)
# Out:
# False

# %% [markdown]
# ## 1. Determine who's home cluster center is in ZONE

# %%
def insideZone(p):
    if p==None:
        return False
    else:
        return p.within(zone)

# %%
vuln = []
non_vuln = []
for idx, u in enumerate(users):
    if (insideZone(get_home_cluster_center(u))):
        vuln.append(u)
    else:
        non_vuln.append(u)
    sys.stderr.write("\r"+str(idx+1))
sys.stderr.write("\rDone...")
sys.stderr.write("Identified {0} vulnerable users and {1} non-vulnerable".format(len(vuln),len(non_vuln)))
# Out:
# Done...Identified 233 vulnerable users and 1684 non-vulnerable

# %%
if not os.path.exists(output_directory):
    os.mkdir(output_directory)

# %% [markdown]
# ## 2. Write out just the GeoVulnerable, just in case we need them for something later

# %%
def safe_mapping(p):
    if p==None or np.isnan(p).any():
        return None
    else:
        return mapping(p)
def safe_json_export(args):
    df, path = args
    df = df.copy()
    uName = df.head(1).user.values[0].lower()
    df['date'] = df['date'].apply(lambda t: datetime.datetime.strftime(t,'%Y-%m-%dT%H:%M:%SZ'))

    clean = df.where((pd.notnull(df)), None)
    geojson = {"type":"FeatureCollection","features":[]}
    for _, row in clean.iterrows():
        geom = safe_mapping(row.geometry)
        feature = {'type':'Feature',
                   'geometry':geom,
                   'properties':row.to_dict()
                    }
        del feature['properties']['geometry']
        geojson['features'].append(feature)
    
    with open(path+"/"+uName+'.geojson','w') as oFile:
        json.dump(geojson, oFile)

# %%
for idx, u in enumerate(vuln):
    safe_json_export((u,output_directory))
    sys.stderr.write("\r{0} processed".format(idx+1))
# Out:
# 233 processed

# %% [markdown]
# # 3. Prepare for Analysis
#
# All of these users should already exist in a format prepared for visualizing, these users can be pasted into Google Sheets

# %%
for uName in sorted([u.user[0].lower() for u in vuln]):
    print(uName)
# Out:
# 831tobias
# _an_oak_tree_
# adrianamisoul
# aeclearwater
# afranks3
# agate86
# agreatbigcity
# aladesnr
# amanda_xtelle
# anessava
# annyrr_
# antgetsbitches
# ariramku
# arnellmilton
# arojass
# aviva4ever
# azzi_84
# beatzzzz
# beliebinfinate
# bencashfarouq
# bennygordo
# bigjoe1022
# bobspivak1
# bohunkca
# brendad1121
# brianaaanicolee
# bridgetekelly
# britescrnmedia
# broyumad
# bryanfuhr
# byronbradshaw
# carlysamp
# carminenyc
# cavemanrobles
# celinejade_
# cem3
# chinkeyeyez3
# chissyn
# chris_legaspi
# chrisrodemeyer
# cindychipz
# ckanal
# cnysurvivor1
# continuumcycles
# cooper_smith
# coreybhale
# damianmonzillo
# danaamathews
# danialvarezpr
# dargamogirl
# dark_iceberg
# dcamz5
# dee9996
# dem_callmi_tutu
# diogomontes
# dj2020
# dj_vasquezz
# dommydom24
# downtownmag
# drewgould
# drwho131
# e_m0n3y
# eddiegeenyc
# edelsingh
# eelain212
# elisesp
# emmarocks
# ericabrooke12
# erinfetherston
# ethanfixell
# explicit_clutch
# fanlyeduardo
# faridkader
# fdnybagpiper
# followmdm
# g0ttalov3him
# gabesantacruz10
# garyalonynyc
# georgiaafowler
# georgieeeninjaa
# gkor29
# goldjenna
# gryffindor_kate
# haileygilesacts
# hairwelove
# heatherjeanhd
# homagebrooklyn
# honeyberk
# ianrios
# ikebrooker
# imryanelizabeth
# irishdavenyspur
# ivanper4
# jackedandtandan
# jaclyn_collins
# jahmezzdagawd
# jamesbruni
# jameskiernan
# jameslkimmel
# jamesmarotta_
# jamesshowell
# jamiealexandraa
# janaer64
# japan2021
# jcelona_
# jennaylean
# jeremyscong
# jevicak
# jlsykes
# john_flip11
# johnjschwarz
# jojohankey
# jonmcl
# joshisagoodman
# jotton
# jsuk
# julianandsara
# justmealiseo
# kaitlynohagan
# kat_pugacheva
# katcatoure
# keisharose_
# keniehuber
# kevsall
# kflow94
# killerfemme
# kmfmack
# ladygaga11228
# lalahearts
# laumc822
# laurakazam
# lauren_morra
# laurenatkiehls
# lightoutsrock
# liliyabdrakhman
# lindsaykordik
# lindseyhankes
# lmoskus
# loneladyrider
# lucida_console
# lucraze
# lunaparkconeyis
# lutherriggs_dj
# m3lissasays
# maderised
# mallorymcmorrow
# marisa_fuller
# markmoravits
# marky_mark34
# marotin507
# mastachand
# masterjao
# mattaningram
# max_not_mark
# mediadarwin
# mikedizon
# mikeviktorenko
# missmochalatte2
# mkduffy518
# moishgeorge86
# morgansteve
# mrspuertorico
# muchotoomucho
# myluvisking
# mzmimi_82
# nemsfyl
# nicholaspclarke
# nick_jordan
# nmassa1208
# noahsussman
# notliterallysho
# nrmstyles
# nyicecream
# nyloves_1d
# nzavaa
# objorionto
# oceanofminds
# omargotkicks
# onicadiana
# paigedietz
# pattyyunen
# porcelina1023
# princessdds
# pullacky
# qtwiddaboot
# rafat
# raydelrae
# readyrock7
# realjustinkim
# realkathattack
# realsarp
# reginaontheroad
# robertkohr
# robyntomlin
# rockawaytrading
# rollingstoned40
# samispolished
# sandeeglam
# sarahphara_tw
# sean_manion
# sephology
# sfloridia98
# shaila
# skiftnews
# smoshysydney
# solomonliou
# sotnakny
# squish108
# steketee
# stepliana
# sweterlitsch
# t_o_m_3
# tabeek
# taftcard
# therealgowanus
# therealjeffeis
# thisisdanstweet
# tiffhere
# tigerthedj
# trimarchi023
# typewrighter
# umakhouny
# unclonghorn
# univer_soul
# uthmanbaksh
# vdonikian
# vivalajenna2012
# whistlesandbeer
# wizbyf
# wsb66
# ygross
# zacrivera
# zaffi

# %%
len(vuln)
# Out:
# 356

# %% [markdown]
# # Create rules file from UID

# %%
rules = []
these_rules = []
for idx,u in enumerate(vuln):

    rule = "from:"+u.uid[0]
    these_rules.append(rule)
    
    if idx%25==0 and idx>0:
        rules.append(" OR ".join(these_rules))
        these_rules = []

output = []
for r in rules:
    output.append({"value":r})

with open('../../GNIP/Sandy/NJ_GeoVulnerable_Contextual/rules.json','w') as oFile:
    json.dump(output, oFile)
