# %% [markdown]
# # Are users home locations in Vulnerable Locations?

# %%
import pandas as pd; import numpy as np; from multiprocessing import Pool, Manager; import numpy as np; import geopandas as gpd
import matplotlib.pyplot as plt; import seaborn as sns
import matplotlib, os, json, sys, time, datetime
from bson import json_util

# %%
input_directory  = "/data/chime/geo2/PROCESSED/NYC/ZoneC_Stage2/"
output_directory = "/data/chime/geo2/PROCESSED/NYC/ZoneC_Stage3/"
zoneGeometry     = "../EvacuationZones/NewYorkCity/EvacZoneC.shp"

# %% [markdown]
# #### Import the ZoneA Geometry

# %%
import fiona, shapely; from osgeo import ogr; from shapely.geometry import mapping, shape
c = fiona.open(zoneGeometry,'r')
pol = c.next(); zone = shape(pol['geometry']).buffer(0); zone.is_valid
# Out:
# True

# %% [markdown]
# #### Import the user metadata DF (Phasing this out)

# %%
_user_meta = pd.read_json(input_directory+'/temporal_clustered_user_meta.json')

# %%
_user_meta = _user_meta.sort_index()
_user_meta.head(3)
# Out:
#    home_cluster                                home_cluster_coords  tweets  \
# 0           1.0  {"type": "Point", "coordinates": [-73.69247457...   14231
# 1           1.0  {"type": "Point", "coordinates": [-73.85111675...   12269
# 2           1.0  {"type": "Point", "coordinates": [-73.89503632...    9005
#
#          uid           user
# 0   75153082  Andrewthemark
# 1   63998299  Young_Boss501
# 2  389770680     bodet4real

# %% [markdown]
# ## 0. Import all of the individual user dataframes

# %%
users_in = sorted(os.listdir(input_directory))
users_in = [x for x in users_in if x != "temporal_clustered_user_meta.json"]
print("Found {0} users in {1}".format(len(users_in), input_directory))
# Out:
# Found 4321 users in /data/chime/geo2/PROCESSED/NYC/ZoneC_Stage2/

# %%
def loader_function(args):
    uFile, path, q = args
    u = json.load(open(path+"/"+uFile,'r'))
    tweets = []
    for t in u['features']:
        if t['geometry']:
            t['properties']['geometry'] = shape(t['geometry'])
        t['properties']['date'] = pd.Timestamp(t['properties']['date'])
        tweets.append(t['properties'])
    q.put(1)
    return gpd.GeoDataFrame(tweets)

# %%
#Parallel runtime
p = Pool(30)
m = Manager()
q = m.Queue()

args = [(i, input_directory, q) for i in users_in]
result = p.map_async(loader_function, args)

# monitor loop
while True:
    if result.ready():
        break
    else:
        size = q.qsize()
        sys.stderr.write("\rProcessed: {0}, {1:.3g}%".format(size, size/len(args)*100))
        time.sleep(0.5)
sys.stderr.write("\rProcessed: {0}, {1:.3g}%".format(q.qsize(), q.qsize()/len(args)*100))
users = result.get()
p.close()
# Out:
# Processed: 4321, 100%

# %%
users.sort( key=lambda x: len(x), reverse=True )

# %% [markdown]
# `users` is an array of user dataframes. Now find which users have _home locations_ in Zone A

# %%
x = users[100]
print(len(x))
x.head(1)
# Out:
# 1266
#    cluster                                     cluster_center  \
# 0        1  {"type": "Point", "coordinates": [-73.87101960...
#
#                         coords                      date  day_cluster  \
# 0  [-73.87100266, 40.67371242] 2012-09-01 01:41:48+00:00            6
#
#    geo_delta                          geometry  home_cluster_id  speed  \
# 0        NaN  POINT (-73.87100266 40.67371242)              1.0    NaN
#
#                                                 text  time_delta  \
# 0  I'm at Visions Of Beauty Unisex Salon (Brookly...         NaN
#
#              tweet_id       uid            user
# 0  241712430592442368  19243536  TeshawnEdmonds

# %%
def get_home_cluster_center(userDF):
    return shape(json.loads(userDF.query('cluster=='+str(userDF.home_cluster_id.values[0])).cluster_center.values[0]))

get_home_cluster_center(users[0]).within(zone)
# Out:
# False

# %% [markdown]
# ## 1. Determine who's home cluster center is in ZONE

# %%
def insideZone(p):
    if p==None:
        return False
    else:
        return p.within(zone)

# %%
vuln = []
non_vuln = []
for idx, u in enumerate(users):
    if (insideZone(get_home_cluster_center(u))):
        vuln.append(u)
    else:
        non_vuln.append(u)
    sys.stderr.write("\r"+str(idx+1))
sys.stderr.write("\rDone...")
sys.stderr.write("Identified {0} vulnerable users and {1} non-vulnerable".format(len(vuln),len(non_vuln)))
# Out:
# Done...Identified 1103 vulnerable users and 3218 non-vulnerable

# %%
if not os.path.exists(output_directory):
    os.mkdir(output_directory)

# %% [markdown]
# ## 2. Write out just the GeoVulnerable, just in case we need them for something later

# %%
def safe_mapping(p):
    if p==None or np.isnan(p).any():
        return None
    else:
        return mapping(p)
def safe_json_export(args):
    df, path = args
    df = df.copy()
    uName = df.head(1).user.values[0].lower()
    df['date'] = df['date'].apply(lambda t: datetime.datetime.strftime(t,'%Y-%m-%dT%H:%M:%SZ'))

    clean = df.where((pd.notnull(df)), None)
    geojson = {"type":"FeatureCollection","features":[]}
    for _, row in clean.iterrows():
        geom = safe_mapping(row.geometry)
        feature = {'type':'Feature',
                   'geometry':geom,
                   'properties':row.to_dict()
                    }
        del feature['properties']['geometry']
        geojson['features'].append(feature)
    
    with open(path+"/"+uName+'.geojson','w') as oFile:
        json.dump(geojson, oFile)

# %%
for idx, u in enumerate(vuln):
    safe_json_export((u,output_directory))
    sys.stderr.write("\r{0} processed".format(idx+1))
# Out:
# 1103 processed

# %% [markdown]
# # 3. Prepare for Analysis
#
# All of these users should already exist in a format prepared for visualizing, these users can be pasted into Google Sheets

# %%
for uName in sorted([u.user[0].lower() for u in vuln]):
    print(uName)
# Out:
# 1229journal
# 19megu91
# 5awaga
# 7aflatna
# 7onegang
# _born_trini
# _dbourret
# _dizzle_10
# _fanitani
# _henrymartinez
# _itscastro
# _joseestevez
# _natma
# _shelbella
# a0k
# aaretz
# abenzion
# abiet90
# aboboeric
# acidjacknyc
# actheveny
# ad454
# ad_mayra
# adampdouglas
# addjeff
# adri_sofia
# adventureofdomo
# afburialgrndnps
# afcinnyc
# ahil23
# ahrom
# airony26
# aivilostm
# ajb613
# akballon
# akm_nyc
# alangrabinsky
# albamescudi
# alcdp
# alewifey
# alexaizenberg
# alexmoseman
# alhothaliabdul
# ali_jane322
# alibackman
# alisoneroman
# allahjust
# alliegallo
# allihagendorf
# alltimetara4
# allybmartin
# alyssenicole
# alyssvav
# amadeophoto
# amelzbdealz
# americahires
# amirkaz
# amparo__sanchez
# amstel89
# andersonortiz29
# andrewandrew
# andrewmaldo
# andrewmgalvan
# andrewsrowe
# andrzj_vrbzj
# andyjohnjoseph
# angel_4eva
# angeleduardoc
# angeljimenez
# angiexx94
# anildash
# anjelika_kour
# ant_faria_
# anthonydramirez
# anthonymichaei
# anthoulakats
# antpulido
# araghandour
# aranzavillalobs
# arimeisel
# arimwhite
# armindak
# arnmukh11
# arodriguez1215
# artealf
# ashaf08
# ememcool
# emjags
# emmaaaaaax3
# emmahenson
# emmasoret
# emmasphere212
# emtvpr
# eoghandillon
# eppyboy
# erickinnyc
# ericmichaelnyc
# erikacuesta_
# erikarsampaio
# erkutcakmak
# escoemartinez
# estherlevy1
# etailjobs
# eunicek
# evanmcmurry
# evaochoa
# ewood02
# eyeofthemaluk
# ez2bnicee
# fadialejandro
# fadingad
# fashionjunkey
# felixcepeda8
# felixsalmon
# fenderjazz
# fernandofaraldo
# fernandoherz77
# fgiann02
# fgonzalez2323
# fjv5
# florentinabl
# flushing95
# followrabbits
# frankthetank91
# freakstyle1
# freshkid5159
# functime
# funnychristine
# furi4prez
# gabrielle913
# gavinluvbeyonce
# gchase
# gdiddy277
# geezieff
# geminirhymeorit
# genjisan
# geolatu51
# georgegoglz
# georgehahn
# gerald_walker
# gerryvisco
# getspajobs
# gilesmcgrath
# gillennium
# gingerails
# gisselatinoco
# giuseppex718
# givenchycp
# gizzimo
# glitter122
# gmanzueta24
# godfatherad
# godslittleradio
# gogogadge7
# gothamlove
# goto10
# gqbreed
# graceicon
# graograman
# greghoward88
# gsbeauchamp
# gtstons
# guestlistblog
# gwb
# hadleydkeller
# hamburger
# hannahkuo
# harlanvaughn
# harlem_stories_
# hautetalk
# hdlost
# hdupont1
# hel3ni
# helijah97
# hempsteadjobs
# heyguey
# hikenyc
# hippolovee
# hiren1012
# hirshi
# hollisterhovey
# hollyfabs
# hoodheroent
# hooliaclaire
# hospitalonheels
# hragv
# hty_jrock
# huebschie
# hyevinkim
# i_am_nyq
# i_l_g
# iamjennifair
# iamlilnat
# iamromanh
# iamsanjar
# ian_glazer
# ifnckbothsexes
# igstorres
# ihartkb
# ikardashiankidd
# iley_xoxo
# ill_ny
# ilovecenax360
# imakeufit
# imperatormagnus
# incessantnoyes
# infinitynewsnet
# itsadam
# itslafitz
# itstherealnia
# ivanit_a
# izayaaallat
# jacobpritchard
# jacobsond10
# jacobunderwood
# jadetribe
# jaeselle
# jahsonmc
# jakepip
# jakeyyedid
# jamaal30
# jamaica1971
# jamaicanmastert
# jameela13
# jamiebhernandez
# jandrjr
# jaredn84
# jarog4
# jasonhueman
# jasonllichtman
# jaylarubinelli
# jayroc1nyc
# jayzu
# jchisenhall
# jcitto
# jcm_mejia91
# jdlevite
# jeancarlos809
# jeannie2430
# jedi_jjo
# jedilaforce321
# jeffqxr
# jeffreybinney
# jenaeex33
# jenbecksz
# jengrunwald
# jennbatinjane
# jenndontstop
# jennicolemarie
# jennpalombo
# jennydeluxe
# jennylubkin
# jennymorrone
# jephburton
# jerehunt
# jerry_sandoval
# jerrygarcia202
# jessi_lembo
# jessiarrington
# jetillyer
# jewelisa_xo
# jhubb
# jillianhaney
# jims_whim
# jj_schreffler
# jlee1181
# jmc_pgh
# jmplanche
# joannaoconnell
# jobsdirectusa
# joelallouz
# joeluckyyt
# joeymacs
# johannabotta
# johndavynoxmen
# johndeguzman
# johnharrington
# johnlancia
# johnnybabz
# johnscottreed
# johnsto
# joliecantina
# jollyroget
# jolwoir1
# jonclarkjr
# jonvox
# jorgeizzle
# jorgiecakes
# josephmizrahi
# joshbarone
# joshjvelez
# joshrachlin
# joyamanasseh
# movelikejaglall
# mpc100
# mpitzke
# mrsince86
# mrtrwilliger
# mrtwyst
# mryoungambition
# msbelt
# msliryc
# mstrbrown
# muncheeznyc
# mutantmanchild
# muzicman424
# mykeycoccia
# myladyfriend
# myraaalynn
# mzz_flawless
# nastyern
# nataliegrillon
# natefrench18
# nathdawg
# naturalbeautydc
# nchirls
# nefeligeorgala
# neilyadig
# nic_x0x
# niccccyo
# nickonken
# nikelii
# nikkibogopo
# nikkotw
# nikoseftaxias
# ninammfoto
# ninasoley
# ninoprodigio
# niqyirar
# nishishi26
# nkneessy
# nkoalaspeaks
# nm_summo
# nmknyc
# nnebeluk
# noemirockz
# noneck
# noobsbt
# noochieboochies
# notsewdadonna
# nvmuzik
# ny2nc23
# ny_night_train
# nyclaur
# nycspicebo
# nyrambler
# ohdeerdrygoods
# ohhmylucas
# olaforsstrom
# omarabreu92
# onlywhatican
# ooooooashley
# operagaga
# p00nie
# pacliboi04
# pamdaexpress
# pamelavenbass
# pandjonb
# papa_ubu
# patagonianyc
# patbhenderson
# patriciorobayo
# patrickdsweeney
# paula2christine
# paula_andrea017
# paulschlacter
# paytonismissing
# pdimezzzz
# pequody
# perla016
# petelyf
# peteramckay
# peterknox
# peterrahbar
# petertmaxwelljr
# petroleumj
# phridric1
# pinkladysteph
# pinkrose1003
# pl3ss
# playbillmattb
# pleasedept
# plummer03
# popeofgvillage
# popomoso
# poppikramer
# positivepushnyc
# pretty_g1rlswag
# princessarcelay
# princesslove__
# profpizza
# punkponey
# pwedieboy
# q_raider
# qpid1985
# quintonma
# r0b_f0rd
# r8d_8_king
# raashibhalla
# rachel_berryman
# rachelannstuart
# rachelksimon
# rachelmcjackson
# rachidrouis
# rafael_demarco
# rafaeldiaznyc
# rah_unique
# rahrah300
# rana_dola
# randyescabi24
# raquelsx3
# rayangarcia
# rayonthecrayon
# realtybaron
# rebtask
# redfabbri
# reeree1020
# refinery29
# regalosmargot
# relpango
# reneeheartsnyc
# reporterkhtv
# reubenhernandez
# rheacamilla
# riannam
# ricenbeats
# richard_scholl
# richardgin
# richconsolazio
# richzerbo
# rickvick999
# riedelx333
# riozilla
# risarenay
# rivkind
# rjruiz20
# ro1112
# robertgarland
# robinson_ny
# robotbigfoot
# robrusso
# roebasile
# rognyc77
# rollingturtle
# ronmeister03
# ronniegallant
# rorydale
# roystanfield
# rspberryeggplnt
# ruben5400
# russskova
# rvillacarillo
# ryanarenson
# ryder_ripps
# ryeisenberg
# sabrinamartin98
# saldaleo
# salvadorsorian5
# samhendel
# samiliebman
# samselfpublish
# samuel_myles
# saphireness
# sarahbachmann
# sarahdulat
# sarahrabby
# sarahsarahowen
# sarkauff
# sarsurakg
# sassysam1201
# savorymango
# schenwow
# sconnellan
# scorpio_lust
# screamradius
# sdadich
# sdavar
# seanlynam
# seanr1978
# sgtfelicity
# shallonhunter
# shaneorr
# shannamckay
# sharpguys
# shaunleelewis
# shawnindawn
# shay6661
# sheamc
# sheeravenue
# shefindsjulie
# shelbypaiget
# shellypalmer
# shida2_raunchy
# shineinovertime
# shurshik14
# sim1_castillo
# sim1hill
# simplydemii
# siscovanilla
# sjflorio
# sk4iland
# sky_fly85
# slutherhandbags
# smacur
# sn0wcap
# snowballsmom
# sofia_esnaola
# sofiapaz1227
# sol666soul
# somethingsnarky
# songadaymann
# sonnysofrito
# sophiagurule
# soverigntruth
# specdotsign
# spinsterlicious
# spuytenduyvilny
# stacymackler
# stankillian
# stefanpenner
# stellar_jl319
# steph_m_rod
# stephanielee13
# stephen_dejesus
# stephiejeanne
# stephmarieexoxo
# stephso
# stevecarmonanow
# stfleury
# stfuindy
# stillhip
# stina_remo
# stolper
# street_pepper
# stsilent
# studiowerk
# sugarspade
# sullybronxny
# sunshinetaylor
# supastar76
# superbaddrohadd
# superlerka
# suppernyc
# surfnbrew
# sweetnlu
# sydneyreising
# taaramariie
# taaysabs
# talesofarentboy
# tanphill
# tarkilus
# tattooedgirl69
# taylorbaldwin
# tbird_twin
# tcsayyys
# tdevlin87
# teachitkate
# teaforpaige
# teasefire
# tensafefrogs
# teshawnedmonds
# tessa
# thebigyek
# theblackoutblog
# thecorpsecorps
# thedantaylor
# theeverettross
# thegitch
# theglow123
# thegyrohero
# thejackamo
# themattmager
# themidwestgirl
# themisshapes
# thenycnomad
# therealalig87
# therealtavia
# thericolaw
# thisisheatherc
# thisizcheech
# threadsalt
# thvtnxggv_
# tiffany_xjz420
# tiffers002
# tigerchen
# tililorre
# tinababersz
# tokyo_gaijin
# tolar
# tolgarnyc
# tomarthur
# tonyjohansson_
# tootnanny
# torrduer
# townsendhagen
# tracygloverjr
# trebor728
# treice255
# trentjwidrick
# trevnyc
# truck8
# trueroselotus
# trust509
# tsmeeton
# ttrainers
# turrneygeehaha
# tylr
# tyonjreid
# ues_bella
# ultraclay
# unicornho
# unsarah
# urbanmystique
# usuckyo
# val_molina
# valentinaeffe
# valerysmallwood
# vcaiola32
# vcmcmullen
# vennifer
# victorjusto2
# villagebroker
# vioreltanase
# vivalaglam7
# vohit4rohit
# vonmichaelnnyc
# vontoastmasta
# vonveezy5000
# vseidel1984
# waffle_friess
# wakeupmrkim
# waptryteam
# washheightsbttm
# waynegblum
# wdnsday
# wear3y0ung
# wendyvasquezz
# wepeters
# wesleytjohnson
# whattheelle
# whereismarcus
# williamalvarez
# williamtier
# willtrainer008
# wilmorvillalobo
# woah_its_camden
# xavierleal18
# xelerose
# xiehan
# xmariacrisx
# xoxodesire
# yaboilani
# yalitzaruiz
# yangbin88olp
# yatown_news_am
# yawetse
# yaypril
# yeeda89
# yeny_lanegra
# yesskriss
# yogi__fierce
# yokevin
# yoooooo0o
# youngmikelp
# youngspanish143
# youpokadot
# your_daily_pill
# yourlordjason
# yourscheid
# ys_huamani
# yummyapril
# yungrecklessfun
# z4three
# zabackj
# zacharycohen
# zachaustin
# zaradusaal
# zkubin
# zoebruck
# zonaerrorlucho
# zuffysomindless

# %%
len(vuln)
# Out:
# 1103

# %% [markdown]
# # Create rules file from UID

# %%
rules = []
these_rules = []
for idx,u in enumerate(vuln):

    rule = "from:"+u.uid[0]
    these_rules.append(rule)
    
    if idx%25==0 and idx>0:
        rules.append(" OR ".join(these_rules))
        these_rules = []

output = []
for r in rules:
    output.append({"value":r})

with open('../../GNIP/Sandy/NJ_GeoVulnerable_Contextual/rules.json','w') as oFile:
    json.dump(output, oFile)
