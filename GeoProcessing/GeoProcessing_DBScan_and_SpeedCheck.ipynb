# %% [markdown]
# # GeoProcessing:
#
# ## DBScan: Cluster Analysis of every user's location
# ## Speed Processing (Check if a user's reported speeds are even possible!)
#
# Using DBScan, find spatial clusters relevant to each user, typically home, work, or school

# %%
import os, json, matplotlib, iso8601, sys
from shapely.geometry import shape
from multiprocessing import Pool; 
import numpy as np; import pandas as pd; import geopandas as gpd
from dbscan_python import dbscan
from geodistance import geodistance
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
users_with_tweets_in_zone_a = sorted(os.listdir('../working_data/all_tweets_from_zoneA_users/'))
len(users_with_tweets_in_zone_a)
# Out:
# 21951

# %%
"""
    Input: User .geojsonl file
    Returns: DataFrame with speed & clusters

    #Process
    1. Loads all of a user's tweets (parseable json per line, parse, strip down to details, sort by time)
    2. Computes Clusters based on below EPS & MIN_PTS
    3. Computes time, distance, and speed between each tweet
    4. Puts it all into a DataFrame
"""

def worker_function(user_geojsonl_file):
    EPS     = 100     #Max. Distance for points in the cluster...                                                                                                                   
    MIN_PTS = 5       #Minimum Points in a cluster  
    tweets = []
    for line in open('../working_data/all_tweets_from_zoneA_users/'+user_geojsonl_file,'r'):
        t = json.loads(line.strip())
        stripped = {
                'geometry': shape(t['geometry']),
                'coords'  : t['geometry']['coordinates'],
                'date'    : iso8601.parse_date(t['properties']['postedTime']),
                'text'    : t['properties']['body'],
                'user'    : t['properties']['actor']['preferredUsername']
            }
        tweets.append(stripped)
    if len(tweets)==1:
        return None
    #Ensure we're sorted by time:
    tweets.sort(key=lambda t: t['date'])

    #Clustering:
    points = [t['coords'] for t in tweets]
    m = np.array([ [p[1] for p in points], [p[0] for p in points] ])
    clusters = dbscan.dbscan(m, EPS, MIN_PTS)
    
    #Iterate through, assign clusters & calculate distance
    for idx, t in enumerate(tweets):
        t['cluster'] = clusters[idx]
        if idx>0:
            p1 = t['geometry']
            p2 = tweets[idx-1]['geometry']
            t['geo_delta'] = geodistance.distanceHaversine(p1.y,p1.x,p2.y,p2.x)[0]*1000
    
    #Now we can finally do the dataframe bullshit...
    df = gpd.GeoDataFrame(tweets)
    df['time_delta'] = df['date'].diff()
    df['speed'] = df.apply(lambda row: row['geo_delta']/ (row['time_delta'] / np.timedelta64(1, 's')), axis=1)
    return df

# %%
#Parallel runtime
pool = Pool(24)
res = pool.map_async(worker_function, users_with_tweets_in_zone_a)
pool.close()
pool.join()

# %%
user_dfs = res.get()

# %%
len(user_dfs)
# Out:
# 21951

# %%
dfs = [df for df in user_dfs if type(df) != type(None) ]

# %%
len(dfs)
# Out:
# 20533

# %%
def safe_json_export(df):
    path = '../working_data/clustered_with_speed/'
    df = df.copy()
    df['date'] = df['date'].apply(lambda t: datetime.datetime.strftime(t,'%Y-%m-%dT%H:%M:%SZ'))
    df['time_delta'] = df['time_delta'] / np.timedelta64(1, 's')
    uName = df.head(1).user.values[0].lower()
    with open(path+uName+'.geojson','w') as oFile:
        oFile.write(df.to_json(ensure_ascii=False))

# %%
#Parallel runtime
pool = Pool(24)
for i, _ in enumerate(pool.imap_unordered(safe_json_export,  dfs[1:]), 1):
    sys.stderr.write('\rdone {0:%}'.format(i/len(dfs)))
pool.close()
pool.join()
# Out:
# done 99.995130%

# %%
import datetime, pytz

# %%
# Will Move this to temporal processing after we can serialize these dataframes better :) 
def check_before_and_after(df):
    _before   = datetime.datetime(2012,10,29,8,0,0,tzinfo=pytz.UTC) #Noon
    _landfall = datetime.datetime(2012,10,30,0,0,0,tzinfo=pytz.UTC) #8pm EST
    _after    = datetime.datetime(2012,10,31,0,0,0,tzinfo=pytz.UTC) #8pm EST
    
    tweets_during_landfall_p1 = df[df['date'] > _before]
    tweets_during_landfall    = tweets_during_landfall_p1[tweets_during_landfall_p1['date'] < _after]
    
    if len(tweets_during_landfall) > 1:
        return tweets_during_landfall
    else:
        return None
check_before_and_after(dfs[0])

# %%
atLandfall = [check_before_and_after(x) for x in dfs]

# %%
atLandfallReal = [x for x in atLandfall if type(x) != type(None)]

# %%
landfallers = sorted(atLandfallReal, key=lambda x: len(x), reverse=True)

# %%
landfallers[0].head(1).user.values[0]
# Out:
# 'OhOhOhItsJoHnNy'

# %%
len(landfallers)
# Out:
# 3289

# %%
with open('landfallers.csv','w') as oFile:
    for u in landfallers:
        oFile.write(u.head(1).user.values[0] + "," + str(len(u))+"\n")

# %%
x = landfallers[0]

# %%
impossible_speeds = []

# %%
for u in landfallers:
    if len(u[u.speed > 240]) > 0:
        impossible_speeds.append(u)

# %%
impossible_speeds[1].sort(['speed'], ascending=False)
# Out:
#       cluster                       coords                      date  \
# 7678      1.0  [-73.69155924, 40.67355939] 2012-10-29 19:32:38+00:00
# 7617      1.0   [-73.6914688, 40.67339842] 2012-10-29 16:42:39+00:00
# 7683      1.0  [-73.69156565, 40.67344721] 2012-10-29 19:43:30+00:00
# 7616      NaN   [-73.70763115, 40.6577251] 2012-10-29 16:42:02+00:00
# 7681      1.0  [-73.69156509, 40.67332976] 2012-10-29 19:39:43+00:00
# 7722      1.0  [-73.69149302, 40.67348894] 2012-10-29 21:51:51+00:00
# 7682      1.0  [-73.70452144, 40.68082512] 2012-10-29 19:42:51+00:00
# 7679      1.0  [-73.69839532, 40.66922998] 2012-10-29 19:34:32+00:00
# 7710      1.0   [-73.69197708, 40.6730437] 2012-10-29 21:07:07+00:00
# 7653      1.0  [-73.69135128, 40.67362364] 2012-10-29 17:40:42+00:00
# 7602      1.0  [-73.69150073, 40.67373742] 2012-10-29 16:31:57+00:00
# 7721      1.0  [-73.69327949, 40.67498682] 2012-10-29 21:51:40+00:00
# 7689      1.0  [-73.69277307, 40.67275438] 2012-10-29 19:54:59+00:00
# 7690      1.0  [-73.69151473, 40.67355243] 2012-10-29 19:56:03+00:00
# 7671      1.0  [-73.69146394, 40.67359925] 2012-10-29 18:05:56+00:00
# 7618      1.0  [-73.69158443, 40.67345043] 2012-10-29 16:42:45+00:00
# 7599      1.0  [-73.69151171, 40.67358085] 2012-10-29 16:27:43+00:00
# 7693      1.0  [-73.69272814, 40.67441181] 2012-10-29 19:59:40+00:00
# 7698      1.0  [-73.69144214, 40.67356354] 2012-10-29 20:41:37+00:00
# 7685      1.0  [-73.69151029, 40.67364405] 2012-10-29 19:46:40+00:00
# 7604      1.0  [-73.69156712, 40.67355663] 2012-10-29 16:33:03+00:00
# 7680      1.0  [-73.70071846, 40.66773801] 2012-10-29 19:39:04+00:00
# 7601      1.0  [-73.69107365, 40.67381451] 2012-10-29 16:31:43+00:00
# 7681                @PSDoubleHoSeven it's a joke Parker  Andrewthemark
# 7722                                    Welp. #BlackOut  Andrewthemark
# 7682                            @HEELWrestling y joel y  Andrewthemark
# 7679                              @SpellingFucker maybe  Andrewthemark
# 7710                               @Figure4HedgeHog yes  Andrewthemark
# 7653                       Poor New Jersey #PrayForMark  Andrewthemark
# 7602              @NickRedMachine TWO FUCKING DAYS NICK  Andrewthemark
# 7721  @JJTheMark looking forward to playing wwe 13 t...  Andrewthemark
# 7689                                  @KeatonPrinceW no  Andrewthemark
# 7690                                  @JoeBewick thanks  Andrewthemark
# 7671                       Ign livestream at 3 bah gawd  Andrewthemark
# 7618                                @vgamer19 yeah same  Andrewthemark
# 7599                               BRB going for a swim  Andrewthemark
# 7693                            @DontMentionLove random  Andrewthemark
# 7698                                     @vgamer19 yolo  Andrewthemark
# 7685                           @HEELWrestling oh thanks  Andrewthemark
# 7604                              @realjasonrivera wow.  Andrewthemark
# 7680                                 @vgamer19 2005 irl  Andrewthemark
# 7601  WHAT A 9/10 FOR WWE 13 WHAT THEY FUCK WHOSE GI...  Andrewthemark
# 7609                            @MarcusHaight damnnnnnn  Andrewthemark
# 7716                                    @E__RAGE about?  Andrewthemark
# 7610       New Jersey's got in bad bah gawd poor Marcus  Andrewthemark
# 7630                                       #PrayForMark  Andrewthemark
# 7677                                  @JoeBewick barely  Andrewthemark
# 7606   @TruChains ign or game informer i don't remember  Andrewthemark
# 7711                                         @E__RAGE y  Andrewthemark
# ...                                                 ...            ...
# 7600  GUYS GUY GUYS MY DAD CANCELED SCHOOL AGAIN TOM...  Andrewthemark
# 7595     Welp, guess i'm going back to school tomorrow.  Andrewthemark
# 7730                               Hope i'm stable by 8  Andrewthemark
# 7731  @Wrestle_React really sucks. Luckily, i'm head...  Andrewthemark
# 7593        @clinteldorado @nickredmachine inb4 blocked  Andrewthemark
# 7634                I hope i have power for Raw tonight  Andrewthemark
# 7638       @yeahimkristin i'm in a hurricane, i'm calm.  Andrewthemark
# 7639         @MarcusHaight @yeahimkristin this is true.  Andrewthemark
# 7654              The fire department is on stand by :/  Andrewthemark
# 7673                      @ImDanielHimself it feels gr8  Andrewthemark
# 7672           @UndeadEagle BITCH DID YOUR POWER GO OUT  Andrewthemark
# 7668                         Leaves everywhere bah gawd  Andrewthemark
# 7665                              @ImDanielHimself Mark  Andrewthemark
# 7664                              @ImDanielHimself kthx  Andrewthemark
# 7663                                  @Aeroparats never  Andrewthemark
# 7662                @MarcusHaight oh thats good to hear  Andrewthemark
# 7659          @MarcusHaight fuck. How do you have wifi?  Andrewthemark
# 7658  @Aeroparats when i got it, the dvd froze in th...  Andrewthemark
# 7651   @Mark4Mahal yeah, the whole North East of the US  Andrewthemark
# 7643        Why couldn't wwe 13 have come out yesterday  Andrewthemark
# 7699         @Figure4HedgeHog @vgamer19 cux he's a cunt  Andrewthemark
# 7650                  Cory Ledesma has the worst tweets  Andrewthemark
# 7649                                @SpellingFucker lol  Andrewthemark
# 7648  Welp, i guess i'll just play fetch with my dog...  Andrewthemark
# 7703                                     @JJTheMark GT?  Andrewthemark
# 7647              Watching South Park while i still can  Andrewthemark
# 7646                       @MarcusHaight where are you?  Andrewthemark
# 7645                        @SpellingFucker whats a god  Andrewthemark
# 7644                                    #ScumbagKristin  Andrewthemark
# 7661    @MarcusHaight oh the phone lines still working?  Andrewthemark
#
#       time_delta      speed
# 7678    00:00:00        inf
# 7617    00:00:37  59.800300
# 7683    00:00:39  35.032754
# 7616    00:01:09  32.048151
# 7681    00:00:39  25.416338
# 7722    00:00:11  20.416980
# 7682    00:03:08   7.309560
# 7679    00:01:54   6.588561
# 7710    00:00:15   3.772403
# 7653    00:00:22   3.369331
# 7602    00:00:14   2.644523
# 7721    00:01:29   2.519666
# 7689    00:01:03   2.258572
# 7690    00:01:04   2.161477
# 7671    00:00:13   1.982096
# 7618    00:00:06   1.889586
# 7599    00:00:13   1.844902
# 7693    00:01:21   1.600776
# 7698    00:00:12   1.358903
# 7685    00:00:21   1.065714
# 7604    00:00:20   1.043403
# 7680    00:04:32   0.943881
# 7601    00:00:50   0.903297
# 7609    00:00:23   0.760796
# 7716    00:00:10   0.701905
# 7610    00:00:39   0.664718
# 7630    00:00:19   0.658172
# 7677    00:01:13   0.646220
# 7606    00:00:19   0.634095
# 7711    00:01:40   0.578159
# ...          ...        ...
# 7600    00:03:10   0.000000
# 7595    00:00:36   0.000000
# 7730    00:00:12   0.000000
# 7731    00:02:08   0.000000
# 7593    00:00:32   0.000000
# 7634    00:00:25   0.000000
# 7638    00:00:38   0.000000
# 7639    00:02:14   0.000000
# 7654    00:01:04   0.000000
# 7673    00:01:11   0.000000
# 7672    00:00:26   0.000000
# 7668    00:00:25   0.000000
# 7665    00:01:24   0.000000
# 7664    00:00:29   0.000000
# 7663    00:00:55   0.000000
# 7662    00:00:29   0.000000
# 7659    00:00:25   0.000000
# 7658    00:01:16   0.000000
# 7651    00:00:51   0.000000
# 7643    00:00:18   0.000000
# 7699    00:01:17   0.000000
# 7650    00:00:17   0.000000
# 7649    00:00:56   0.000000
# 7648    00:00:47   0.000000
# 7703    00:00:28   0.000000
# 7647    00:01:11   0.000000
# 7646    00:00:19   0.000000
# 7645    00:00:28   0.000000
# 7644    00:00:59   0.000000
# 7661    00:00:17   0.000000
#
# [145 rows x 9 columns]

# %%
#Run it all in parallel?
#http://stackoverflow.com/questions/5666576/show-the-progress-of-a-python-multiprocessing-pool-map-call
# pool = Pool(24)
# res = pool.map_async(check_before_and_after, dfs)
# pool.close()
# pool.join()

# %%
user_dfs = res2.get()
dfs = [df for df in user_dfs if type(df) != type(None) ]

# %%
# Get these usernames into a CSV 
# default_handler #should be able to call the .to_json() method with this argument to serialize the dates?

# %%
test = dfs[1].copy()

# %%
def to_str(x):
    return str(x)

# %%
test = dfs[1].copy()

# %%
test.text
# Out:
# 0     I hate being in the same room of my brother &a...
# 1     Okay let's get this show on the road, hopefull...
# 2     Shit I'm to early, now I have to wait for the ...
# 3     Tired as hell just came from the parade, no af...
# 4     What are the odds of seeing your EX at  a labo...
# 5     I don't know what to do next, I want to go to ...
# 6     I get the best sleep when I'm faded, I wake up...
# 7                        @TheComplexOne88 hiiii buddy 👋
# 8     I miss interesting conversations, Thays ones y...
# 9                                    Porn = 👍👍👍....💤💤💤💤
# 10    @TheComplexOne88 I'm great just exhausted &amp...
# Name: text, dtype: object
